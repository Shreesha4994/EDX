# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('sales.csv')

# %%
df1=pd.read_csv('sales.csv',index_col=['Region','Order ID'])

# %%
df
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
df1
# Out:
#                                                            Country  \
# Region                            Order ID
# Australia and Oceania             669165933                 Tuvalu
# Central America and the Caribbean 963881480                Grenada
# Europe                            341417157                 Russia
# Sub-Saharan Africa                514321792  Sao Tome and Principe
#                                   115456712                 Rwanda
# ...                                                            ...
#                                   512878119                   Mali
# Asia                              810711038               Malaysia
# Sub-Saharan Africa                728815257           Sierra Leone
# North America                     559427106                 Mexico
# Sub-Saharan Africa                665095412             Mozambique
#
#                                                    Item Type Sales Channel  \
# ...

# %%
ht=pd.read_html('index.html')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-12-c9f0ba231690> in <module>
# ----> 1 ht=pd.read_html('index.html')
#
# c:\users\user\appdata\local\programs\python\python37-32\lib\site-packages\pandas\io\html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1098         na_values=na_values,
#    1099         keep_default_na=keep_default_na,
# -> 1100         displayed_only=displayed_only,
#    1101     )
#
# c:\users\user\appdata\local\programs\python\python37-32\lib\site-packages\pandas\io\html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     889     retained = None
#     890     for flav in flavor:
# --> 891         parser = _parser_dispatch(flav)
# ...
