# %%
import pandas as pd

# %%
df=read_csv('qw.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c89e82de90cd> in <module>
# ----> 1 df=read_csv('qw.csv')
#
# NameError: name 'read_csv' is not defined

# %%
df=pd.read_csv('qw.csv')

# %%
print(df)
# Out:
#      School ID                                     NAME_OF_SCHOOL  \
# 0       610038                  Abraham Lincoln Elementary School
# 1       610281  Adam Clayton Powell Paideia Community Academy ...
# 2       610185                Adlai E Stevenson Elementary School
# 3       609993                    Agustin Lara Elementary Academy
# 4       610513                      Air Force Academy High School
# ..         ...                                                ...
# 561     610172                William T Sherman Elementary School
# 562     609844                 William W Carter Elementary School
# 563     610088                Wolfgang A Mozart Elementary School
# 564     609977               Woodlawn Community Elementary School
# 565     610392                 World Language Academy High School
#
#     Elementary, Middle, or High School          Street Address     City State  \
# 0                                   ES        615 W Kemper Pl   Chicago    IL
# ...

# %%
df.head()
# Out:
#    School ID                                     NAME_OF_SCHOOL  \
# 0     610038                  Abraham Lincoln Elementary School
# 1     610281  Adam Clayton Powell Paideia Community Academy ...
# 2     610185                Adlai E Stevenson Elementary School
# 3     609993                    Agustin Lara Elementary Academy
# 4     610513                      Air Force Academy High School
#
#   Elementary, Middle, or High School          Street Address     City State  \
# 0                                 ES        615 W Kemper Pl   Chicago    IL
# 1                                 ES  7511 S South Shore Dr   Chicago    IL
# 2                                 ES     8010 S Kostner Ave   Chicago    IL
# 3                                 ES     4619 S Wolcott Ave   Chicago    IL
# 4                                 HS        3630 S Wells St   Chicago    IL
#
#    ZIP Code    Phone Number  \
# 0     60614  (773) 534-5720
# 1     60649  (773) 535-6650
# 2     60652  (773) 535-2280
# ...

# %%
df.low()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-c5229085b562> in <module>
# ----> 1 df.low()
#
# c:\users\user\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'low'

# %%
df.head(12)
# Out:
#     School ID                                     NAME_OF_SCHOOL  \
# 0      610038                  Abraham Lincoln Elementary School
# 1      610281  Adam Clayton Powell Paideia Community Academy ...
# 2      610185                Adlai E Stevenson Elementary School
# 3      609993                    Agustin Lara Elementary Academy
# 4      610513                      Air Force Academy High School
# 5      610212                  Albany Park Multicultural Academy
# 6      609720                Albert G Lane Technical High School
# 7      610342            Albert R Sabin Elementary Magnet School
# 8      610524              Alcott High School for the Humanities
# 9      610209                 Alessandro Volta Elementary School
# 10     609799            Alexander Graham Bell Elementary School
# 11     609947                 Alexander Graham Elementary School
#
#    Elementary, Middle, or High School          Street Address     City State  \
# ...

# %%
df.column()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-1d60d75b1e24> in <module>
# ----> 1 df.column()
#
# c:\users\user\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'column'

# %%
df.ttaail(9)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-9b68e62beae2> in <module>
# ----> 1 df.ttaail(9)
#
# c:\users\user\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'ttaail'

# %%
df.tail(9)
# Out:
#      School ID                              NAME_OF_SCHOOL  \
# 557     610097           William P Nixon Elementary School
# 558     609711           William Rainey Harper High School
# 559     610232        Williams Multiplex Elementary School
# 560     610336  Williams Preparatory Academy Middle School
# 561     610172         William T Sherman Elementary School
# 562     609844          William W Carter Elementary School
# 563     610088         Wolfgang A Mozart Elementary School
# 564     609977        Woodlawn Community Elementary School
# 565     610392          World Language Academy High School
#
#     Elementary, Middle, or High School        Street Address     City State  \
# 557                                 ES    2121 N Keeler Ave   Chicago    IL
# 558                                 HS       6520 S Wood St   Chicago    IL
# 559                                 ES   2710 S Dearborn St   Chicago    IL
# ...

# %%
df.sample(4)
# Out:
#      School ID                                     NAME_OF_SCHOOL  \
# 336     609807  Lionel Hampton Fine & Performing Arts Elementa...
# 235     610532  Irene C. Hernandez Middle School for the Advan...
# 390     609806  Myra Bradwell Communications Arts & Sciences E...
# 213     609974            Hawthorne Elementary Scholastic Academy
#
#     Elementary, Middle, or High School       Street Address     City State  \
# 336                                 ES      3434 W 77th St   Chicago    IL
# 235                                 MS      3510 W 55th St   Chicago    IL
# 390                                 ES  7736 S Burnham Ave   Chicago    IL
# 213                                 ES  3319 N Clifton Ave   Chicago    IL
#
#      ZIP Code    Phone Number  \
# 336     60652  (773) 535-4030
# 235     60632  (773) 535-8850
# 390     60649  (773) 535-6600
# 213     60657  (773) 534-5550
#
#                                                  Link   \
# ...

# %%
df[['School ID']]
# Out:
#      School ID
# 0       610038
# 1       610281
# 2       610185
# 3       609993
# 4       610513
# ..         ...
# 561     610172
# 562     609844
# 563     610088
# 564     609977
# 565     610392
#
# [566 rows x 1 columns]

# %%
df[['City']]
# Out:
#         City
# 0    Chicago
# 1    Chicago
# 2    Chicago
# 3    Chicago
# 4    Chicago
# ..       ...
# 561  Chicago
# 562  Chicago
# 563  Chicago
# 564  Chicago
# 565  Chicago
#
# [566 rows x 1 columns]

# %%
df[['city']==Chicago]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-a181c9faa887> in <module>
# ----> 1 df[['city']==Chicago]
#
# NameError: name 'Chicago' is not defined

# %%
df[['School ID']<5]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-e153d223eec9> in <module>
# ----> 1 df[['School ID']<5]
#
# TypeError: '<' not supported between instances of 'list' and 'int'

# %%
df.dtypes()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-09616d73ed79> in <module>
# ----> 1 df.dtypes()
#
# TypeError: 'Series' object is not callable

# %%
dtypes(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-99643e64ff08> in <module>
# ----> 1 dtypes(df)
#
# NameError: name 'dtypes' is not defined

# %%
df.describe()
# Out:
#            School ID      ZIP Code  SAFETY_SCORE  Environment Score  \
# count     566.000000    566.000000    513.000000         513.000000
# mean   609681.791519  60629.727915     49.504873          47.766082
# std      8831.060946     20.248024     20.110837          16.215584
# min    400018.000000  60605.000000      1.000000           1.000000
# 25%    609873.250000  60618.000000     35.000000          37.000000
# 50%    610052.500000  60625.000000     48.000000          47.000000
# 75%    610212.750000  60639.000000     61.000000          58.000000
# max    610544.000000  60827.000000     99.000000          99.000000
#
#        Instruction Score  Rate of Misconducts (per 100 students)   \
# count         513.000000                               566.000000
# mean           48.288499                                21.085866
# std            17.417176                                27.543835
# min             1.000000                                 0.000000
# ...
