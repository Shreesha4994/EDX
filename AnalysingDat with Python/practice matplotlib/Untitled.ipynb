# %%
import matplotlib.pyplot as plt
import math
import numpy as np

# %%
a1=[1,2,3,4]
a2=[4,5,7,8]

# %%
plt.title('test file')

plt.plot(a1,a2,'bo')

# %%
y1=map(math.sin(90),math.sin(80))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-248371927075> in <module>
# ----> 1 y1=map(math.sin(90),math.sin(80))
#
# TypeError: 'float' object is not iterable

# %%
t=np.arange(0,9,1)
y1=map(math.sin,math.pi*t)

# %%
plt.plot(t,y1,'b')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-43-2046c86b4b85> in <module>
# ----> 1 plt.plot(t,y1,'b')
#
# c:\users\user\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2763         is not None else {}), **kwargs)
#    2764
#    2765
#
# c:\users\user\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1645         """
#    1646         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1647         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1648         for line in lines:
#    1649             self.add_line(line)
#
# ...

# %%
t=np.arange(0,2.5,0.1)
y1=map(math.sin,math.pi*t)

# %%
plt.plot(t,y1)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-45-39cde8efaf74> in <module>
# ----> 1 plt.plot(t,y1)
#
# c:\users\user\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2763         is not None else {}), **kwargs)
#    2764
#    2765
#
# c:\users\user\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1645         """
#    1646         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1647         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1648         for line in lines:
#    1649             self.add_line(line)
#
# ...

# %%
math.sin(90)
# Out:
# 0.8939966636005579

# %%
for i in range(9):
    print((math.pi/4)*i,"\n",math.sin((math.pi/4)*1))
# Out:
# 0.0
#  0.7071067811865475
# 0.7853981633974483
#  0.7071067811865475
# 1.5707963267948966
#  0.7071067811865475
# 2.356194490192345
#  0.7071067811865475
# 3.141592653589793
#  0.7071067811865475
# 3.9269908169872414
#  0.7071067811865475
# 4.71238898038469
#  0.7071067811865475
# 5.497787143782138
#  0.7071067811865475
# 6.283185307179586
#  0.7071067811865475

# %%
p=map(math.sin,[2,3,4,4])
arr=[]

# %%
for i  in p:
    arr.append(i)

# %%
plt.plot(arr)

# %%
t=np.arange(2,10,2)

# %%
y1=np.sin(t)

# %%
y1
# Out:
# array([ 0.90929743, -0.7568025 , -0.2794155 ,  0.98935825])

# %%
plt.plot(y1)

# %%
x=np.arange(-2*np.pi,2*np.pi,0.01)

# %%
y=np.sin(3*x)/x

# %%
plt.plot(x,y)

# %%
a1=np.arange(1,10,0.1)

# %%
a2=np.sin(a1)+np.pi*(a1+np.log(a1))

# %%
plt.plot(a1,a2)

# %%
a3=a1**3

# %%
plt.plot(a2,a3,'r',a1,a3,'b')
# Out:
# [<matplotlib.lines.Line2D at 0xea2190>, <matplotlib.lines.Line2D at 0xea2270>]

# %%
a4=a1**10+a3*np.pi-a2**7+a1/a2+a1**2

# %%
plt.text(1,2,'test text')
# Out:
# Text(1, 2, 'test text')

# %%
plt.plot(a1,a4,'b',a1,a2,'ro',a1,a3,'g*')

# %%
pop=np.random.randint(0,100,100)

# %%
pop
# Out:
# array([44, 69, 20,  2, 39, 17, 97, 14, 44, 23, 52, 36, 83,  4, 23, 63, 61,
#        77, 73, 24, 94, 11, 52, 26,  6, 14, 38, 35, 49,  3, 22, 45, 73, 63,
#        11, 85, 93, 39, 46, 87, 52, 24, 72, 59,  9, 61, 20, 56,  1, 96, 64,
#        63, 82, 64, 89,  8, 80, 86, 34,  9, 70, 49, 77, 13, 15, 99, 57, 18,
#        39, 13, 26, 61, 47,  0, 25, 52, 75, 15, 75, 93, 94, 90, 23, 31, 47,
#        19, 52, 32, 13, 16, 88, 98, 37, 54, 69, 28, 83, 41, 74, 11])

# %%
n,bins,patches = plt.hist(pop,bins=50)
plt.xlabel("fdg")
plt.ylabel
# Out:
# <function matplotlib.pyplot.ylabel(ylabel, fontdict=None, labelpad=None, **kwargs)>

# %%
a1=np.random.randint(0,100,100)
a2=np.random.randint(0,100,100)

# %%
plt.plot(a1,a2)

# %%
plt.bar(a1,a2)
plt.legend(loc=2)
# Out:
# No handles with labels found to put in legend.

# %%
labels=['dsf','mbnmbsf','piuoif','hgjgj']
values=[23,54,87,25]
colors=['blue','yellow','red','green']
explode=[0,0,0,0.3]
plt.pie(values,labels=labels,colors=colors,explode=explode,shadow=True,autopct='%0.3f%%',startangle=180)

#plt.axis('equal')
# Out:
# ([<matplotlib.patches.Wedge at 0xb1e39d0>,
# ...
#  [Text(-1.020585779419418, -0.4103713767392403, 'dsf'),
#   Text(0.1004242103598971, -1.0954063072547973, 'mbnmbsf'),
#   Text(0.7140451409406702, 0.8367434115061909, 'piuoif'),
#   Text(-1.2808496573153714, 0.5651762161972993, 'hgjgj')],
#  [Text(-0.5566831524105915, -0.22383893276685832, '12.169%'),
#   Text(0.05477684201448932, -0.5974943494117075, '28.571%'),
#   Text(0.38947916778582004, 0.45640549718519496, '46.032%'),
#   Text(-0.82340335113131, 0.3633275675554067, '13.228%')])
